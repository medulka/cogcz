# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme()


data_ar = np.asarray([1, 31, 1, 2, 33, 1, 27, 3, 2, 2, 1, 1, 1, 2, 1, 1, 2, 1, 2, 8, 1, 1, 33, 1, 4, 1, 1, 2, 2, 1, 2, 1, 1, 4, 1, 2, 33, 2, 1, 2, 33, 1, 4, 1, 33, 1, 1, 1, 2, 1, 32, 1, 1, 1, 1, 1, 1, 1, 2, 1, 33, 1, 1, 4, 1, 1, 33, 2, 2, 1, 2, 1, 4, 9, 1, 1, 1, 5, 1, 2, 33, 2, 1, 1, 1, 3, 33, 1, 1])
header = ['N:M234I', 'N:A376T', 'N:R385K', 'ORF1a:A690V', 'ORF1a:M3087I', 'ORF1a:L3606F', 'ORF1b:A176S', 'ORF1b:P314L', 'ORF1b:V767L', 'ORF1b:K1141R', 'ORF1b:E1184D', 'ORF3a:Q57H', 'ORF8:E59*', 'ORF8:I121X', 'S:S477N', 'S:D614G', 'S:A1070V', 'ORF1a:V774I', 'ORF1b:A2143T', 'ORF1b:A2565V', 'ORF3a:W193R', 'N:M210I', 'ORF3a:A99V', 'ORF1a:H110Y', 'ORF1a:T814I', 'ORF1b:P218L', 'ORF1b:P970S', 'ORF1a:L730F', 'ORF1a:I1785V', 'ORF1a:V3718F', 'S:V213M', 'N:T166I', 'S:Q677H', 'ORF1a:S391F', 'ORF1a:A1049V', 'ORF1a:A2097V', 'ORF1a:I3369T', 'ORF3a:V202L', 'ORF7a:P99S', 'ORF1a:A2593V', 'ORF1b:V1984L', 'ORF1b:S2198I', 'ORF1b:K2231N', 'ORF7b:M24I', 'ORF8:W45L', 'ORF1b:R1315C', 'S:I569V', 'ORF1a:T2846I', 'ORF1b:T2040I', 'ORF1b:A2513V', 'ORF3a:D155Y', 'S:G1085A', 'ORF1a:T4159I', 'ORF1b:H2388Y', 'S:A570V', 'ORF1a:G400S', 'ORF1a:T1543I', 'ORF1a:R3368H', 'ORF1b:L1351F', 'ORF1b:G2151D', 'S:A845S', 'ORF1b:S961P', 'N:I337F', 'ORF1a:E93K', 'ORF1b:S2031I', 'ORF3a:A110P', 'E:V62F', 'ORF1b:L1220F', 'ORF1b:L1504F', 'S:M153I', 'N:P396S', 'ORF1a:P309L', 'ORF1a:M3655I', 'ORF3a:A110S', 'ORF3a:D265E', 'ORF1a:L681F', 'ORF1a:T1605I', 'ORF1b:Q1669R', 'ORF7a:A13V', 'S:G261V', 'ORF1a:V106A', 'ORF1a:N3118S', 'ORF1b:H1897Y', 'ORF7b:T40N', 'ORF1a:L1713I', 'ORF1b:V1811F', 'ORF9b:T83I', 'ORF1a:L1559F', 'S:V1230L']
y = ["B.1.160"]

data = pd.DataFrame(data = data_ar, columns = y, index = header) # data - array, columns - list

#color palette
cmap = "YlOrRd"

fig = plt.figure(figsize=(12,8), dpi= 100, facecolor='w', edgecolor='k')
ax = sns.heatmap(data, cmap = cmap, xticklabels = header, yticklabels = y, 
                cbar = True, square = True, lineWidth = .5, figure=fig)
ax.set_title("Mutations in SARS-CoV-2 Variants from Czech Izolates")

# print(dir(ax))
#ax.xaxis.tick_top()
# plt.savefig("/Users/hanamedova/Documents/COG/week20/heatmap_variants_info.png")
# Out:
# /opt/homebrew/Caskroom/miniconda/base/lib/python3.8/site-packages/seaborn/matrix.py:298: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   mesh = ax.pcolormesh(self.plot_data, cmap=self.cmap, **kws)
# Text(0.5, 1.0, 'Mutations in SARS-CoV-2 Variants from Czech Izolates')
